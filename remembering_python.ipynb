# %% [markdown]
# <a href="https://colab.research.google.com/github/ppriatiningtyaz/atm-progate-project/blob/master/remembering_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

a = 1
b = 2
c = a + b
# print(c)

def sum(a, b):
    print(a + b)
# sum(3, 4)

d = [1,2,3,4,5,6]
e = [1,2,2,3,2,1]
plt.plot(d,e)
plt.show()
